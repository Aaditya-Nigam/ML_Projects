# %% [markdown]
# <a href="https://colab.research.google.com/github/Aaditya-Nigam/ML_Projects/blob/main/Project1_StudentPerformance(MultilpeLnearRegression).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dataset: https://www.kaggle.com/datasets/nikhil7280/student-performance-multiple-linear-regression?resource=download

# %%
import numpy as np
import pandas as pd

# %%
dataSet=pd.read_csv("/content/Student_Performance.csv")
dataSet.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
dataSet['Extracurricular Activities']=l.fit_transform(dataSet['Extracurricular Activities'])

# %%
dataSet.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
X=dataSet.iloc[:,:-1]
Y=dataSet.iloc[:,-1]
print(X.shape)
print(Y.shape)
# Out:
# (10000, 5)
# (10000,)

# %%
from matplotlib import pyplot as plt
fig,ax=plt.subplots(1,5, figsize=(18,3))
for i in range(5):
  ax[i].scatter(X.iloc[:,i],Y)
  ax[i].set_xlabel(X.columns[i])
ax[0].set_ylabel("Performance")
# Out:
# Text(0, 0.5, 'Performance')

# %%
from sklearn.model_selection import train_test_split as tts
X_train,X_test,Y_train,Y_test=tts(X,Y,test_size=0.2,random_state=2)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (8000, 5)
# (2000, 5)
# (8000,)
# (2000,)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(Y_test,Y_pred)
accuracy=r2_score(Y_test,Y_pred)
print("MSE: ",mse)
print("Accuracy: ",accuracy*100)
# Out:
# MSE:  4.070278591652593
# Accuracy:  98.90954655668953

# %%
print(model.coef_)
# Out:
# [2.85352109 1.01959723 0.59483017 0.48314352 0.1977199 ]
